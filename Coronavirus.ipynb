# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import os
import glob # Import glob for finding files

# Configurações gerais
EPOCHS = 200
LEARNING_RATE = 2e-3
BATCH_SIZE = 64
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {DEVICE}")

# Caminho para o dataset "Doencas-Olhos"
DATA_DIR = 'datasetsTCC/Coronahack-Chest-XRay-Dataset'

# 1. Definir as transformações da imagem
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# 2. Criar um Dataset customizado para carregar todas as imagens recursivamente
class AllImagesDataset(Dataset):
    def __init__(self, root_dir, transform=None): # Corrected argument name to root_dir
        self.root_dir = root_dir
        self.transform = transform
        # Find all image files (jpg, jpeg, png) recursively
        self.image_files = glob.glob(os.path.join(self.root_dir, '**', '*.jpg'), recursive=True) + \
                           glob.glob(os.path.join(self.root_dir, '**', '*.jpeg'), recursive=True) + \
                           glob.glob(os.path.join(self.root_dir, '**', '*.png'), recursive=True)

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = self.image_files[idx]
        image = Image.open(img_path).convert('RGB') # Open as RGB first to handle different formats

        if self.transform:
            image = self.transform(image)

        return image, 0 # Return image and a dummy label (0) as we don't have class info here

# Carregar o dataset usando o Dataset customizado
# Como não estamos separando treino e teste explicitamente nesta abordagem,
# vamos carregar todas as imagens e depois splitar manualmente se necessário
full_dataset = AllImagesDataset(root_dir=DATA_DIR, transform=transform) # Corrected argument name to root_dir

# Split dataset into train and test (optional, depending on model training needs)
# For autoencoders, often the same data is used for input and target, so a simple split might not be needed
# However, if you want to train on a subset and test on another, uncomment the lines below:
# train_size = int(0.8 * len(full_dataset))
# test_size = len(full_dataset) - train_size
# train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])

# For now, let's use the full dataset for the loader as autoencoders often train on all data
train_loader = DataLoader(full_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(full_dataset, batch_size=BATCH_SIZE, shuffle=False) # Use full dataset for testing visualization

print(f"Número total de imagens encontradas: {len(full_dataset)}")


# Função para visualizar as imagens
def plot_images(original, reconstructed, n=10):
    plt.figure(figsize=(20, 4))
    # Ensure we don't plot more than available images
    num_images_to_plot = min(n, original.size(0))
    for i in range(num_images_to_plot):
        # Imagem original
        ax = plt.subplot(2, num_images_to_plot, i + 1)
        # Desnormaliza a imagem para o intervalo [0, 1] para exibição
        img = original[i].cpu().numpy().squeeze() * 0.5 + 0.5
        plt.imshow(img, cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == num_images_to_plot // 2:
            ax.set_title("Originais")

        # Imagem reconstruída
        ax = plt.subplot(2, num_images_to_plot, i + 1 + num_images_to_plot)
        # Desnormaliza a imagem para o intervalo [0, 1] para exibição
        rec_img = reconstructed[i].cpu().numpy().squeeze() * 0.5 + 0.5
        plt.imshow(rec_img, cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i == num_images_to_plot // 2:
            ax.set_title("Reconstruídas")
    plt.show()
# Out:
# Usando dispositivo: cuda
# Número total de imagens encontradas: 5933

# %%
# 1. Definição do Modelo Vanilla Autoencoder
class ConvolutionalAutoencoder(nn.Module):
    def __init__(self):
        super(ConvolutionalAutoencoder, self).__init__()

        # Encoder: Reduz a imagem espacialmente e aumenta a profundidade (canais)
        self.encoder = nn.Sequential(
            # Entrada: [N, 1, 128, 128] (N = batch_size)
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3, stride=2, padding=1),  # -> [N, 16, 64, 64]
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1), # -> [N, 32, 32, 32]
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1), # -> [N, 64, 16, 16]
            #nn.ReLU(),
            #nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1) # -> [N, 128, 8, 8] (Representação latente)
        )

        self.decoder = nn.Sequential(
            # Entrada: [N, 128, 8, 8]
            #nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 64, 16, 16]
            #nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 32, 32, 32]
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 16, 64, 64]
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),   # -> [N, 1, 128, 128]
            nn.Tanh() # Escala a saída para [-1, 1], igual à normalização da entrada
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# 2. Treinamento do Modelo
model_vanilla = ConvolutionalAutoencoder().to(DEVICE)
criterion = nn.L1Loss()
optimizer = optim.Adam(model_vanilla.parameters(), lr=LEARNING_RATE)

for epoch in range(EPOCHS):
    total_loss = 0
    for data in train_loader:
        images, _ = data
        images = images.to(DEVICE)

        outputs = model_vanilla(images)

        # Achatamos as imagens originais para calcular a perda com a saída achatada do decoder
        # (O modelo já remodela a saída, então comparamos imagens com imagens)
        loss = criterion(outputs, images)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Vanilla AE | Epoch [{epoch+1}/{EPOCHS}], Loss: {total_loss/len(train_loader):.4f}")

# 3. Visualização dos Resultados
print("\n--- Visualizando resultados do Vanilla Autoencoder ---")
with torch.no_grad():
    data_iter = iter(test_loader)
    test_images, _ = next(data_iter)
    test_images = test_images.to(DEVICE)

    reconstructed_images = model_vanilla(test_images)
    plot_images(test_images, reconstructed_images)
# Out:
# Vanilla AE | Epoch [1/200], Loss: 0.1333
# Vanilla AE | Epoch [2/200], Loss: 0.0488
# Vanilla AE | Epoch [3/200], Loss: 0.0385
# Vanilla AE | Epoch [4/200], Loss: 0.0330
# Vanilla AE | Epoch [5/200], Loss: 0.0302
# Vanilla AE | Epoch [6/200], Loss: 0.0278
# Vanilla AE | Epoch [7/200], Loss: 0.0264
# Vanilla AE | Epoch [8/200], Loss: 0.0254
# Vanilla AE | Epoch [9/200], Loss: 0.0247
# Vanilla AE | Epoch [10/200], Loss: 0.0238
# Vanilla AE | Epoch [11/200], Loss: 0.0232
# Vanilla AE | Epoch [12/200], Loss: 0.0227
# Vanilla AE | Epoch [13/200], Loss: 0.0221
# Vanilla AE | Epoch [14/200], Loss: 0.0216
# Vanilla AE | Epoch [15/200], Loss: 0.0213
# Vanilla AE | Epoch [16/200], Loss: 0.0208
# Vanilla AE | Epoch [17/200], Loss: 0.0205
# Vanilla AE | Epoch [18/200], Loss: 0.0200
# Vanilla AE | Epoch [19/200], Loss: 0.0198
# Vanilla AE | Epoch [20/200], Loss: 0.0196
# Vanilla AE | Epoch [21/200], Loss: 0.0192
# Vanilla AE | Epoch [22/200], Loss: 0.0189
# Vanilla AE | Epoch [23/200], Loss: 0.0187
# Vanilla AE | Epoch [24/200], Loss: 0.0186
# Vanilla AE | Epoch [25/200], Loss: 0.0183
# Vanilla AE | Epoch [26/200], Loss: 0.0181
# Vanilla AE | Epoch [27/200], Loss: 0.0180
# Vanilla AE | Epoch [28/200], Loss: 0.0178
# Vanilla AE | Epoch [29/200], Loss: 0.0178
# Vanilla AE | Epoch [30/200], Loss: 0.0175
# Vanilla AE | Epoch [31/200], Loss: 0.0174
# Vanilla AE | Epoch [32/200], Loss: 0.0171
# Vanilla AE | Epoch [33/200], Loss: 0.0170
# Vanilla AE | Epoch [34/200], Loss: 0.0169
# Vanilla AE | Epoch [35/200], Loss: 0.0168
# Vanilla AE | Epoch [36/200], Loss: 0.0166
# Vanilla AE | Epoch [37/200], Loss: 0.0165
# Vanilla AE | Epoch [38/200], Loss: 0.0163
# Vanilla AE | Epoch [39/200], Loss: 0.0162
# Vanilla AE | Epoch [40/200], Loss: 0.0161
# Vanilla AE | Epoch [41/200], Loss: 0.0161
# Vanilla AE | Epoch [42/200], Loss: 0.0159
# Vanilla AE | Epoch [43/200], Loss: 0.0158
# Vanilla AE | Epoch [44/200], Loss: 0.0157
# Vanilla AE | Epoch [45/200], Loss: 0.0155
# Vanilla AE | Epoch [46/200], Loss: 0.0155
# Vanilla AE | Epoch [47/200], Loss: 0.0153
# Vanilla AE | Epoch [48/200], Loss: 0.0152
# Vanilla AE | Epoch [49/200], Loss: 0.0151
# Vanilla AE | Epoch [50/200], Loss: 0.0150
# Vanilla AE | Epoch [51/200], Loss: 0.0149
# Vanilla AE | Epoch [52/200], Loss: 0.0148
# Vanilla AE | Epoch [53/200], Loss: 0.0147
# Vanilla AE | Epoch [54/200], Loss: 0.0147
# Vanilla AE | Epoch [55/200], Loss: 0.0145
# Vanilla AE | Epoch [56/200], Loss: 0.0145
# Vanilla AE | Epoch [57/200], Loss: 0.0144
# Vanilla AE | Epoch [58/200], Loss: 0.0143
# Vanilla AE | Epoch [59/200], Loss: 0.0142
# Vanilla AE | Epoch [60/200], Loss: 0.0142
# Vanilla AE | Epoch [61/200], Loss: 0.0140
# Vanilla AE | Epoch [62/200], Loss: 0.0139
# Vanilla AE | Epoch [63/200], Loss: 0.0140
# Vanilla AE | Epoch [64/200], Loss: 0.0138
# Vanilla AE | Epoch [65/200], Loss: 0.0137
# Vanilla AE | Epoch [66/200], Loss: 0.0138
# Vanilla AE | Epoch [67/200], Loss: 0.0136
# Vanilla AE | Epoch [68/200], Loss: 0.0136
# Vanilla AE | Epoch [69/200], Loss: 0.0135
# Vanilla AE | Epoch [70/200], Loss: 0.0133
# Vanilla AE | Epoch [71/200], Loss: 0.0134
# Vanilla AE | Epoch [72/200], Loss: 0.0132
# Vanilla AE | Epoch [73/200], Loss: 0.0131
# Vanilla AE | Epoch [74/200], Loss: 0.0130
# Vanilla AE | Epoch [75/200], Loss: 0.0131
# Vanilla AE | Epoch [76/200], Loss: 0.0129
# Vanilla AE | Epoch [77/200], Loss: 0.0129
# Vanilla AE | Epoch [78/200], Loss: 0.0128
# Vanilla AE | Epoch [79/200], Loss: 0.0127
# Vanilla AE | Epoch [80/200], Loss: 0.0127
# Vanilla AE | Epoch [81/200], Loss: 0.0126
# Vanilla AE | Epoch [82/200], Loss: 0.0125
# Vanilla AE | Epoch [83/200], Loss: 0.0125
# Vanilla AE | Epoch [84/200], Loss: 0.0125
# Vanilla AE | Epoch [85/200], Loss: 0.0124
# Vanilla AE | Epoch [86/200], Loss: 0.0123
# Vanilla AE | Epoch [87/200], Loss: 0.0123
# Vanilla AE | Epoch [88/200], Loss: 0.0122
# Vanilla AE | Epoch [89/200], Loss: 0.0121
# Vanilla AE | Epoch [90/200], Loss: 0.0122
# Vanilla AE | Epoch [91/200], Loss: 0.0122
# Vanilla AE | Epoch [92/200], Loss: 0.0121
# Vanilla AE | Epoch [93/200], Loss: 0.0119
# Vanilla AE | Epoch [94/200], Loss: 0.0119
# Vanilla AE | Epoch [95/200], Loss: 0.0119
# Vanilla AE | Epoch [96/200], Loss: 0.0118
# Vanilla AE | Epoch [97/200], Loss: 0.0117
# Vanilla AE | Epoch [98/200], Loss: 0.0118
# Vanilla AE | Epoch [99/200], Loss: 0.0116
# Vanilla AE | Epoch [100/200], Loss: 0.0118
# Vanilla AE | Epoch [101/200], Loss: 0.0117
# Vanilla AE | Epoch [102/200], Loss: 0.0116
# Vanilla AE | Epoch [103/200], Loss: 0.0115
# Vanilla AE | Epoch [104/200], Loss: 0.0115
# Vanilla AE | Epoch [105/200], Loss: 0.0114
# Vanilla AE | Epoch [106/200], Loss: 0.0114
# Vanilla AE | Epoch [107/200], Loss: 0.0114
# Vanilla AE | Epoch [108/200], Loss: 0.0113
# Vanilla AE | Epoch [109/200], Loss: 0.0113
# Vanilla AE | Epoch [110/200], Loss: 0.0112
# Vanilla AE | Epoch [111/200], Loss: 0.0111
# Vanilla AE | Epoch [112/200], Loss: 0.0111
# Vanilla AE | Epoch [113/200], Loss: 0.0111
# Vanilla AE | Epoch [114/200], Loss: 0.0111
# Vanilla AE | Epoch [115/200], Loss: 0.0111
# Vanilla AE | Epoch [116/200], Loss: 0.0110
# Vanilla AE | Epoch [117/200], Loss: 0.0109
# Vanilla AE | Epoch [118/200], Loss: 0.0110
# Vanilla AE | Epoch [119/200], Loss: 0.0108
# Vanilla AE | Epoch [120/200], Loss: 0.0108
# Vanilla AE | Epoch [121/200], Loss: 0.0108
# Vanilla AE | Epoch [122/200], Loss: 0.0108
# Vanilla AE | Epoch [123/200], Loss: 0.0107
# Vanilla AE | Epoch [124/200], Loss: 0.0107
# Vanilla AE | Epoch [125/200], Loss: 0.0106
# Vanilla AE | Epoch [126/200], Loss: 0.0106
# Vanilla AE | Epoch [127/200], Loss: 0.0106
# Vanilla AE | Epoch [128/200], Loss: 0.0105
# Vanilla AE | Epoch [129/200], Loss: 0.0105
# Vanilla AE | Epoch [130/200], Loss: 0.0105
# Vanilla AE | Epoch [131/200], Loss: 0.0104
# Vanilla AE | Epoch [132/200], Loss: 0.0103
# Vanilla AE | Epoch [133/200], Loss: 0.0103
# Vanilla AE | Epoch [134/200], Loss: 0.0103
# Vanilla AE | Epoch [135/200], Loss: 0.0103
# Vanilla AE | Epoch [136/200], Loss: 0.0103
# Vanilla AE | Epoch [137/200], Loss: 0.0102
# Vanilla AE | Epoch [138/200], Loss: 0.0102
# Vanilla AE | Epoch [139/200], Loss: 0.0101
# Vanilla AE | Epoch [140/200], Loss: 0.0101
# Vanilla AE | Epoch [141/200], Loss: 0.0101
# Vanilla AE | Epoch [142/200], Loss: 0.0100
# Vanilla AE | Epoch [143/200], Loss: 0.0101
# Vanilla AE | Epoch [144/200], Loss: 0.0100
# Vanilla AE | Epoch [145/200], Loss: 0.0099
# Vanilla AE | Epoch [146/200], Loss: 0.0099
# Vanilla AE | Epoch [147/200], Loss: 0.0099
# Vanilla AE | Epoch [148/200], Loss: 0.0099
# Vanilla AE | Epoch [149/200], Loss: 0.0098
# Vanilla AE | Epoch [150/200], Loss: 0.0098
# Vanilla AE | Epoch [151/200], Loss: 0.0099
# Vanilla AE | Epoch [152/200], Loss: 0.0098
# Vanilla AE | Epoch [153/200], Loss: 0.0098
# Vanilla AE | Epoch [154/200], Loss: 0.0097
# Vanilla AE | Epoch [155/200], Loss: 0.0096
# Vanilla AE | Epoch [156/200], Loss: 0.0097
# Vanilla AE | Epoch [157/200], Loss: 0.0096
# Vanilla AE | Epoch [158/200], Loss: 0.0096
# Vanilla AE | Epoch [159/200], Loss: 0.0096
# Vanilla AE | Epoch [160/200], Loss: 0.0096
# Vanilla AE | Epoch [161/200], Loss: 0.0096
# Vanilla AE | Epoch [162/200], Loss: 0.0096
# Vanilla AE | Epoch [163/200], Loss: 0.0096
# Vanilla AE | Epoch [164/200], Loss: 0.0095
# Vanilla AE | Epoch [165/200], Loss: 0.0094
# Vanilla AE | Epoch [166/200], Loss: 0.0094
# Vanilla AE | Epoch [167/200], Loss: 0.0094
# Vanilla AE | Epoch [168/200], Loss: 0.0095
# Vanilla AE | Epoch [169/200], Loss: 0.0094
# Vanilla AE | Epoch [170/200], Loss: 0.0094
# Vanilla AE | Epoch [171/200], Loss: 0.0094
# Vanilla AE | Epoch [172/200], Loss: 0.0093
# Vanilla AE | Epoch [173/200], Loss: 0.0093
# Vanilla AE | Epoch [174/200], Loss: 0.0093
# Vanilla AE | Epoch [175/200], Loss: 0.0093
# Vanilla AE | Epoch [176/200], Loss: 0.0092
# Vanilla AE | Epoch [177/200], Loss: 0.0092
# Vanilla AE | Epoch [178/200], Loss: 0.0093
# Vanilla AE | Epoch [179/200], Loss: 0.0091
# Vanilla AE | Epoch [180/200], Loss: 0.0093
# Vanilla AE | Epoch [181/200], Loss: 0.0092
# Vanilla AE | Epoch [182/200], Loss: 0.0092
# Vanilla AE | Epoch [183/200], Loss: 0.0092
# Vanilla AE | Epoch [184/200], Loss: 0.0091
# Vanilla AE | Epoch [185/200], Loss: 0.0091
# Vanilla AE | Epoch [186/200], Loss: 0.0091
# Vanilla AE | Epoch [187/200], Loss: 0.0091
# Vanilla AE | Epoch [188/200], Loss: 0.0091
# Vanilla AE | Epoch [189/200], Loss: 0.0091
# Vanilla AE | Epoch [190/200], Loss: 0.0091
# Vanilla AE | Epoch [191/200], Loss: 0.0091
# Vanilla AE | Epoch [192/200], Loss: 0.0090
# Vanilla AE | Epoch [193/200], Loss: 0.0090
# Vanilla AE | Epoch [194/200], Loss: 0.0090
# Vanilla AE | Epoch [195/200], Loss: 0.0091
# Vanilla AE | Epoch [196/200], Loss: 0.0090
# Vanilla AE | Epoch [197/200], Loss: 0.0090
# Vanilla AE | Epoch [198/200], Loss: 0.0090
# Vanilla AE | Epoch [199/200], Loss: 0.0090
# Vanilla AE | Epoch [200/200], Loss: 0.0090
#
# --- Visualizando resultados do Vanilla Autoencoder ---

# %% [markdown]
# Autoencoder VAE

# %%
class ConvolutionalVAE(nn.Module):
    def __init__(self, latent_dim=32): # Adjusted latent_dim
        super(ConvolutionalVAE, self).__init__()

        # --- ENCODER ---
        # Converte a imagem de entrada em um vetor de características achatado
        self.encoder_conv = nn.Sequential(
            # Input: [N, 1, 128, 128] - Supondo imagem em escala de cinza
            nn.Conv2d(1, 16, kernel_size=4, stride=2, padding=1), # -> [N, 16, 64, 64] - Adjusted channels
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=4, stride=2, padding=1), # -> [N, 32, 32, 32] - Adjusted channels
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1), # -> [N, 64, 16, 16] - Adjusted channels
            nn.ReLU(),
        )

        # Achatamos a saída da convolução e passamos por uma camada linear
        # O tamanho 64 * 16 * 16 vem da saída da última camada Conv2d
        self.flattened_size = 64 * 16 * 16 # Adjusted size

        # Duas camadas lineares para gerar mu e log_var
        self.fc_mu = nn.Linear(self.flattened_size, latent_dim)
        self.fc_log_var = nn.Linear(self.flattened_size, latent_dim)

        # --- DECODER ---
        # Camada linear para começar a expansão a partir do espaço latente
        self.decoder_fc = nn.Linear(latent_dim, self.flattened_size)

        # Camadas convolucionais transpostas para reconstruir a imagem
        self.decoder_conv = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1), # -> [N, 32, 32, 32] - Adjusted channels
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1), # -> [N, 16, 64, 64] - Adjusted channels
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=4, stride=2, padding=1), # -> [N, 1, 128, 128] - Adjusted channels
            nn.Tanh() # Usamos Sigmoid para escalar a saída para [0, 1]
        )

    def reparameterize(self, mu, log_var):
        """O Truque da Reparametrização."""
        std = torch.exp(0.5 * log_var)  # std = sqrt(variance) = sqrt(exp(log_var)) = exp(0.5 * log_var)
        eps = torch.randn_like(std)     # Gera um erro aleatório com a mesma forma de std
        return mu + eps * std           # Retorna a amostra z

    def forward(self, x):
        # 1. Passa pela parte convolucional do encoder e achata
        h = self.encoder_conv(x)
        h = h.view(-1, self.flattened_size)

        # 2. Obtém mu e log_var
        mu = self.fc_mu(h)
        log_var = self.fc_log_var(h)

        # 3. Obtém a amostra z usando o truque da reparametrização
        z = self.reparameterize(mu, log_var)

        # 4. Passa z pelo decoder para reconstruir a imagem
        recon_h = self.decoder_fc(z)
        recon_h = recon_h.view(-1, 64, 16, 16) # Remodela para o formato de imagem antes das convoluções transpostas - Adjusted size
        recon_x = self.decoder_conv(recon_h)

        return recon_x, mu, log_var

def loss_function(recon_x, x, mu, log_var, beta=0.1): # Adicione beta como argumento
    # Perda de Reconstrução com Mean Squared Error
    RECON_LOSS = nn.functional.mse_loss(recon_x, x, reduction='sum')

    # Divergência KL (permanece a mesma)
    KLD = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())

    # Retorna a perda ponderada
    return RECON_LOSS + beta * KLD

# 2. Treinamento do Modelo
model_vae = ConvolutionalVAE().to(DEVICE)
optimizer = optim.Adam(model_vae.parameters(), lr=1e-3)

for epoch in range(EPOCHS):
    total_loss = 0
    for data in train_loader:
        images, _ = data
        images = images.to(DEVICE)

        # Forward pass
        recon_images, mu, log_var = model_vae(images)
        loss = loss_function(recon_images, images, mu, log_var, beta = 0.1)

        # Backward pass e otimização
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader.dataset)
    print(f"VAE | Epoch [{epoch+1}/{EPOCHS}], Average Loss: {avg_loss:.4f}")

print("\n--- Visualizando resultados do VAE Autoencoder ---")
with torch.no_grad():
    data_iter = iter(test_loader)
    test_images, _ = next(data_iter)
    test_images = test_images.to(DEVICE)

    reconstructed_images, _, _ = model_vae(test_images)
    plot_images(test_images, reconstructed_images)
# Out:
# VAE | Epoch [1/200], Average Loss: 1330.4947
# VAE | Epoch [2/200], Average Loss: 456.5651
# VAE | Epoch [3/200], Average Loss: 361.8713
# VAE | Epoch [4/200], Average Loss: 325.3335
# VAE | Epoch [5/200], Average Loss: 303.1394
# VAE | Epoch [6/200], Average Loss: 289.3074
# VAE | Epoch [7/200], Average Loss: 281.5753
# VAE | Epoch [8/200], Average Loss: 273.7926
# VAE | Epoch [9/200], Average Loss: 269.3330
# VAE | Epoch [10/200], Average Loss: 265.8901
# VAE | Epoch [11/200], Average Loss: 259.0128
# VAE | Epoch [12/200], Average Loss: 255.4783
# VAE | Epoch [13/200], Average Loss: 251.9759
# VAE | Epoch [14/200], Average Loss: 249.3285
# VAE | Epoch [15/200], Average Loss: 246.8507
# VAE | Epoch [16/200], Average Loss: 245.0846
# VAE | Epoch [17/200], Average Loss: 242.8697
# VAE | Epoch [18/200], Average Loss: 239.5076
# VAE | Epoch [19/200], Average Loss: 237.5345
# VAE | Epoch [20/200], Average Loss: 236.1178
# VAE | Epoch [21/200], Average Loss: 233.6954
# VAE | Epoch [22/200], Average Loss: 233.6723
# VAE | Epoch [23/200], Average Loss: 230.1058
# VAE | Epoch [24/200], Average Loss: 228.3762
# VAE | Epoch [25/200], Average Loss: 227.3837
# VAE | Epoch [26/200], Average Loss: 226.3852
# VAE | Epoch [27/200], Average Loss: 224.3973
# VAE | Epoch [28/200], Average Loss: 226.3506
# VAE | Epoch [29/200], Average Loss: 221.6462
# VAE | Epoch [30/200], Average Loss: 220.7628
# VAE | Epoch [31/200], Average Loss: 219.5720
# VAE | Epoch [32/200], Average Loss: 217.5433
# VAE | Epoch [33/200], Average Loss: 217.9782
# VAE | Epoch [34/200], Average Loss: 217.3943
# VAE | Epoch [35/200], Average Loss: 217.7388
# VAE | Epoch [36/200], Average Loss: 214.4684
# VAE | Epoch [37/200], Average Loss: 212.6325
# VAE | Epoch [38/200], Average Loss: 212.6607
# VAE | Epoch [39/200], Average Loss: 211.9584
# VAE | Epoch [40/200], Average Loss: 211.0456
# VAE | Epoch [41/200], Average Loss: 210.0145
# VAE | Epoch [42/200], Average Loss: 208.8354
# VAE | Epoch [43/200], Average Loss: 207.8216
# VAE | Epoch [44/200], Average Loss: 207.1515
# VAE | Epoch [45/200], Average Loss: 208.0003
# VAE | Epoch [46/200], Average Loss: 207.0371
# VAE | Epoch [47/200], Average Loss: 205.7979
# VAE | Epoch [48/200], Average Loss: 203.6399
# VAE | Epoch [49/200], Average Loss: 202.7663
# VAE | Epoch [50/200], Average Loss: 201.6674
# VAE | Epoch [51/200], Average Loss: 202.0819
# VAE | Epoch [52/200], Average Loss: 201.9383
# VAE | Epoch [53/200], Average Loss: 203.0699
# VAE | Epoch [54/200], Average Loss: 200.8860
# VAE | Epoch [55/200], Average Loss: 200.2087
# VAE | Epoch [56/200], Average Loss: 198.6819
# VAE | Epoch [57/200], Average Loss: 198.2570
# VAE | Epoch [58/200], Average Loss: 198.4803
# VAE | Epoch [59/200], Average Loss: 197.7210
# VAE | Epoch [60/200], Average Loss: 196.5027
# VAE | Epoch [61/200], Average Loss: 195.2855
# VAE | Epoch [62/200], Average Loss: 195.4293
# VAE | Epoch [63/200], Average Loss: 196.6326
# VAE | Epoch [64/200], Average Loss: 194.9848
# VAE | Epoch [65/200], Average Loss: 194.3834
# VAE | Epoch [66/200], Average Loss: 194.2842
# VAE | Epoch [67/200], Average Loss: 192.5480
# VAE | Epoch [68/200], Average Loss: 191.8682
# VAE | Epoch [69/200], Average Loss: 191.3704
# VAE | Epoch [70/200], Average Loss: 191.0448
# VAE | Epoch [71/200], Average Loss: 190.7680
# VAE | Epoch [72/200], Average Loss: 191.2135
# VAE | Epoch [73/200], Average Loss: 191.3200
# VAE | Epoch [74/200], Average Loss: 192.2654
# VAE | Epoch [75/200], Average Loss: 191.5460
# VAE | Epoch [76/200], Average Loss: 190.8678
# VAE | Epoch [77/200], Average Loss: 188.3413
# VAE | Epoch [78/200], Average Loss: 187.5287
# VAE | Epoch [79/200], Average Loss: 187.0839
# VAE | Epoch [80/200], Average Loss: 186.4489
# VAE | Epoch [81/200], Average Loss: 187.0592
# VAE | Epoch [82/200], Average Loss: 188.1174
# VAE | Epoch [83/200], Average Loss: 186.0067
# VAE | Epoch [84/200], Average Loss: 185.0991
# VAE | Epoch [85/200], Average Loss: 185.4058
# VAE | Epoch [86/200], Average Loss: 185.3092
# VAE | Epoch [87/200], Average Loss: 184.4455
# VAE | Epoch [88/200], Average Loss: 184.2959
# VAE | Epoch [89/200], Average Loss: 184.2400
# VAE | Epoch [90/200], Average Loss: 184.1511
# VAE | Epoch [91/200], Average Loss: 183.6085
# VAE | Epoch [92/200], Average Loss: 183.2247
# VAE | Epoch [93/200], Average Loss: 184.4539
# VAE | Epoch [94/200], Average Loss: 183.7372
# VAE | Epoch [95/200], Average Loss: 183.2688
# VAE | Epoch [96/200], Average Loss: 184.1164
# VAE | Epoch [97/200], Average Loss: 183.1127
# VAE | Epoch [98/200], Average Loss: 180.9135
# VAE | Epoch [99/200], Average Loss: 180.1327
# VAE | Epoch [100/200], Average Loss: 179.9585
# VAE | Epoch [101/200], Average Loss: 180.3688
# VAE | Epoch [102/200], Average Loss: 180.3845
# VAE | Epoch [103/200], Average Loss: 181.6031
# VAE | Epoch [104/200], Average Loss: 179.6424
# VAE | Epoch [105/200], Average Loss: 190.9683
# VAE | Epoch [106/200], Average Loss: 181.5950
# VAE | Epoch [107/200], Average Loss: 180.2567
# VAE | Epoch [108/200], Average Loss: 178.5512
# VAE | Epoch [109/200], Average Loss: 177.9491
# VAE | Epoch [110/200], Average Loss: 177.7908
# VAE | Epoch [111/200], Average Loss: 176.8475
# VAE | Epoch [112/200], Average Loss: 177.6699
# VAE | Epoch [113/200], Average Loss: 177.7961
# VAE | Epoch [114/200], Average Loss: 176.8612
# VAE | Epoch [115/200], Average Loss: 176.4468
# VAE | Epoch [116/200], Average Loss: 177.2336
# VAE | Epoch [117/200], Average Loss: 177.1489
# VAE | Epoch [118/200], Average Loss: 176.2744
# VAE | Epoch [119/200], Average Loss: 176.0605
# VAE | Epoch [120/200], Average Loss: 175.8200
# VAE | Epoch [121/200], Average Loss: 175.6361
# VAE | Epoch [122/200], Average Loss: 175.4755
# VAE | Epoch [123/200], Average Loss: 175.9160
# VAE | Epoch [124/200], Average Loss: 176.6168
# VAE | Epoch [125/200], Average Loss: 174.6935
# VAE | Epoch [126/200], Average Loss: 175.1786
# VAE | Epoch [127/200], Average Loss: 174.0324
# VAE | Epoch [128/200], Average Loss: 176.3273
# VAE | Epoch [129/200], Average Loss: 184.8210
# VAE | Epoch [130/200], Average Loss: 175.7655
# VAE | Epoch [131/200], Average Loss: 172.7048
# VAE | Epoch [132/200], Average Loss: 172.7434
# VAE | Epoch [133/200], Average Loss: 172.2599
# VAE | Epoch [134/200], Average Loss: 172.1755
# VAE | Epoch [135/200], Average Loss: 172.0476
# VAE | Epoch [136/200], Average Loss: 171.5032
# VAE | Epoch [137/200], Average Loss: 170.9569
# VAE | Epoch [138/200], Average Loss: 172.1743
# VAE | Epoch [139/200], Average Loss: 171.9784
# VAE | Epoch [140/200], Average Loss: 171.5942
# VAE | Epoch [141/200], Average Loss: 172.2160
# VAE | Epoch [142/200], Average Loss: 171.3029
# VAE | Epoch [143/200], Average Loss: 170.8097
# VAE | Epoch [144/200], Average Loss: 171.0445
# VAE | Epoch [145/200], Average Loss: 171.9098
# VAE | Epoch [146/200], Average Loss: 170.9910
# VAE | Epoch [147/200], Average Loss: 171.4539
# VAE | Epoch [148/200], Average Loss: 171.6547
# VAE | Epoch [149/200], Average Loss: 170.9349
# VAE | Epoch [150/200], Average Loss: 170.2129
# VAE | Epoch [151/200], Average Loss: 169.8659
# VAE | Epoch [152/200], Average Loss: 169.8584
# VAE | Epoch [153/200], Average Loss: 170.3118
# VAE | Epoch [154/200], Average Loss: 169.5551
# VAE | Epoch [155/200], Average Loss: 169.3002
# VAE | Epoch [156/200], Average Loss: 170.0539
# VAE | Epoch [157/200], Average Loss: 169.8151
# VAE | Epoch [158/200], Average Loss: 169.9178
# VAE | Epoch [159/200], Average Loss: 169.8404
# VAE | Epoch [160/200], Average Loss: 169.0329
# VAE | Epoch [161/200], Average Loss: 168.5162
# VAE | Epoch [162/200], Average Loss: 168.5739
# VAE | Epoch [163/200], Average Loss: 168.6532
# VAE | Epoch [164/200], Average Loss: 167.7669
# VAE | Epoch [165/200], Average Loss: 168.3239
# VAE | Epoch [166/200], Average Loss: 168.8229
# VAE | Epoch [167/200], Average Loss: 168.0706
# VAE | Epoch [168/200], Average Loss: 168.1392
# VAE | Epoch [169/200], Average Loss: 170.2254
# VAE | Epoch [170/200], Average Loss: 167.8218
# VAE | Epoch [171/200], Average Loss: 166.7804
# VAE | Epoch [172/200], Average Loss: 166.9912
# VAE | Epoch [173/200], Average Loss: 166.4021
# VAE | Epoch [174/200], Average Loss: 166.7088
# VAE | Epoch [175/200], Average Loss: 166.8365
# VAE | Epoch [176/200], Average Loss: 167.4537
# VAE | Epoch [177/200], Average Loss: 167.4336
# VAE | Epoch [178/200], Average Loss: 166.9831
# VAE | Epoch [179/200], Average Loss: 166.4071
# VAE | Epoch [180/200], Average Loss: 166.6004
# VAE | Epoch [181/200], Average Loss: 166.1966
# VAE | Epoch [182/200], Average Loss: 166.2833
# VAE | Epoch [183/200], Average Loss: 165.8763
# VAE | Epoch [184/200], Average Loss: 165.8426
# VAE | Epoch [185/200], Average Loss: 167.2726
# VAE | Epoch [186/200], Average Loss: 166.8817
# VAE | Epoch [187/200], Average Loss: 165.3314
# VAE | Epoch [188/200], Average Loss: 164.9283
# VAE | Epoch [189/200], Average Loss: 164.4927
# VAE | Epoch [190/200], Average Loss: 165.2676
# VAE | Epoch [191/200], Average Loss: 165.3553
# VAE | Epoch [192/200], Average Loss: 165.3382
# VAE | Epoch [193/200], Average Loss: 165.8051
# VAE | Epoch [194/200], Average Loss: 164.8940
# VAE | Epoch [195/200], Average Loss: 165.8879
# VAE | Epoch [196/200], Average Loss: 164.9201
# VAE | Epoch [197/200], Average Loss: 164.1619
# VAE | Epoch [198/200], Average Loss: 164.4325
# VAE | Epoch [199/200], Average Loss: 164.5410
# VAE | Epoch [200/200], Average Loss: 164.3119
#
# --- Visualizando resultados do VAE Autoencoder ---

# %% [markdown]
# Denoising AutoEncoder

# %%
# 1. Definição do Modelo Denoising Autoencoder
class DenoisingAutoencoder(nn.Module):
    def __init__(self):
        super(DenoisingAutoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            # Entrada: [N, 1, 128, 128] (N = batch_size)
            nn.Conv2d(in_channels=1, out_channels=16, kernel_size=3, stride=2, padding=1),  # -> [N, 16, 64, 64]
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1), # -> [N, 32, 32, 32]
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1), # -> [N, 64, 16, 16]
            #nn.ReLU(),
            #nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1) # -> [N, 128, 8, 8] (Representação latente)
        )

        self.decoder = nn.Sequential(
            # Entrada: [N, 128, 8, 8]
            #nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 64, 16, 16]
            #nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 32, 32, 32]
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1), # -> [N, 16, 64, 64]
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),   # -> [N, 1, 128, 128]
            nn.Tanh() # Escala a saída para [-1, 1], igual à normalização da entrada
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        decoded = decoded.view(x.size(0), 1, 128, 128) # Remodela de volta para o formato de imagem
        return decoded

# 2. Treinamento do Modelo
model_denoising = DenoisingAutoencoder().to(DEVICE)
criterion = nn.L1Loss()
optimizer = optim.Adam(model_denoising.parameters(), lr=LEARNING_RATE)
noise_factor = 0.1 # Fator de ruído

for epoch in range(EPOCHS):
    total_loss = 0
    for data in train_loader:
        images, _ = data
        images = images.to(DEVICE)

        # Adicionar ruído às imagens de entrada
        noisy_images = images + noise_factor * torch.randn(*images.shape, device=DEVICE)
        noisy_images = torch.clamp(noisy_images, -1., 1.) # Manter no intervalo [-1, 1]

        # A entrada é ruidosa, mas a saída desejada é a imagem limpa
        outputs = model_denoising(noisy_images)
        loss = criterion(outputs, images) # Compara a saída com a imagem original

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Denoising AE | Epoch [{epoch+1}/{EPOCHS}], Loss: {total_loss/len(train_loader):.4f}")

# 3. Visualização dos Resultados
print("\n--- Visualizando resultados do Denoising Autoencoder ---")
with torch.no_grad():
    data_iter = iter(test_loader)
    test_images, _ = next(data_iter)
    test_images = test_images.to(DEVICE)

    # Cria uma versão ruidosa para visualização
    noisy_test_images = test_images + noise_factor * torch.randn(*test_images.shape, device=DEVICE)
    noisy_test_images = torch.clamp(noisy_test_images, -1., 1.)

    reconstructed_images = model_denoising(noisy_test_images)

    # Plotamos a imagem ruidosa (entrada) e a imagem reconstruída (saída)
    plot_images(noisy_test_images, reconstructed_images)
# Out:
# Denoising AE | Epoch [1/200], Loss: 0.1292
# Denoising AE | Epoch [2/200], Loss: 0.0520
# Denoising AE | Epoch [3/200], Loss: 0.0430
# Denoising AE | Epoch [4/200], Loss: 0.0396
# Denoising AE | Epoch [5/200], Loss: 0.0378
# Denoising AE | Epoch [6/200], Loss: 0.0363
# Denoising AE | Epoch [7/200], Loss: 0.0354
# Denoising AE | Epoch [8/200], Loss: 0.0349
# Denoising AE | Epoch [9/200], Loss: 0.0343
# Denoising AE | Epoch [10/200], Loss: 0.0337
# Denoising AE | Epoch [11/200], Loss: 0.0334
# Denoising AE | Epoch [12/200], Loss: 0.0332
# Denoising AE | Epoch [13/200], Loss: 0.0329
# Denoising AE | Epoch [14/200], Loss: 0.0328
# Denoising AE | Epoch [15/200], Loss: 0.0324
# Denoising AE | Epoch [16/200], Loss: 0.0324
# Denoising AE | Epoch [17/200], Loss: 0.0321
# Denoising AE | Epoch [18/200], Loss: 0.0320
# Denoising AE | Epoch [19/200], Loss: 0.0319
# Denoising AE | Epoch [20/200], Loss: 0.0319
# Denoising AE | Epoch [21/200], Loss: 0.0317
# Denoising AE | Epoch [22/200], Loss: 0.0315
# Denoising AE | Epoch [23/200], Loss: 0.0314
# Denoising AE | Epoch [24/200], Loss: 0.0316
# Denoising AE | Epoch [25/200], Loss: 0.0311
# Denoising AE | Epoch [26/200], Loss: 0.0312
# Denoising AE | Epoch [27/200], Loss: 0.0311
# Denoising AE | Epoch [28/200], Loss: 0.0310
# Denoising AE | Epoch [29/200], Loss: 0.0309
# Denoising AE | Epoch [30/200], Loss: 0.0311
# Denoising AE | Epoch [31/200], Loss: 0.0307
# Denoising AE | Epoch [32/200], Loss: 0.0307
# Denoising AE | Epoch [33/200], Loss: 0.0307
# Denoising AE | Epoch [34/200], Loss: 0.0306
# Denoising AE | Epoch [35/200], Loss: 0.0305
# Denoising AE | Epoch [36/200], Loss: 0.0307
# Denoising AE | Epoch [37/200], Loss: 0.0304
# Denoising AE | Epoch [38/200], Loss: 0.0303
# Denoising AE | Epoch [39/200], Loss: 0.0304
# Denoising AE | Epoch [40/200], Loss: 0.0302
# Denoising AE | Epoch [41/200], Loss: 0.0303
# Denoising AE | Epoch [42/200], Loss: 0.0302
# Denoising AE | Epoch [43/200], Loss: 0.0302
# Denoising AE | Epoch [44/200], Loss: 0.0301
# Denoising AE | Epoch [45/200], Loss: 0.0301
# Denoising AE | Epoch [46/200], Loss: 0.0299
# Denoising AE | Epoch [47/200], Loss: 0.0300
# Denoising AE | Epoch [48/200], Loss: 0.0299
# Denoising AE | Epoch [49/200], Loss: 0.0299
# Denoising AE | Epoch [50/200], Loss: 0.0299
# Denoising AE | Epoch [51/200], Loss: 0.0298
# Denoising AE | Epoch [52/200], Loss: 0.0297
# Denoising AE | Epoch [53/200], Loss: 0.0299
# Denoising AE | Epoch [54/200], Loss: 0.0296
# Denoising AE | Epoch [55/200], Loss: 0.0298
# Denoising AE | Epoch [56/200], Loss: 0.0296
# Denoising AE | Epoch [57/200], Loss: 0.0298
# Denoising AE | Epoch [58/200], Loss: 0.0295
# Denoising AE | Epoch [59/200], Loss: 0.0296
# Denoising AE | Epoch [60/200], Loss: 0.0295
# Denoising AE | Epoch [61/200], Loss: 0.0295
# Denoising AE | Epoch [62/200], Loss: 0.0294
# Denoising AE | Epoch [63/200], Loss: 0.0295
# Denoising AE | Epoch [64/200], Loss: 0.0294
# Denoising AE | Epoch [65/200], Loss: 0.0294
# Denoising AE | Epoch [66/200], Loss: 0.0293
# Denoising AE | Epoch [67/200], Loss: 0.0293
# Denoising AE | Epoch [68/200], Loss: 0.0293
# Denoising AE | Epoch [69/200], Loss: 0.0293
# Denoising AE | Epoch [70/200], Loss: 0.0293
# Denoising AE | Epoch [71/200], Loss: 0.0294
# Denoising AE | Epoch [72/200], Loss: 0.0292
# Denoising AE | Epoch [73/200], Loss: 0.0291
# Denoising AE | Epoch [74/200], Loss: 0.0293
# Denoising AE | Epoch [75/200], Loss: 0.0292
# Denoising AE | Epoch [76/200], Loss: 0.0291
# Denoising AE | Epoch [77/200], Loss: 0.0291
# Denoising AE | Epoch [78/200], Loss: 0.0290
# Denoising AE | Epoch [79/200], Loss: 0.0292
# Denoising AE | Epoch [80/200], Loss: 0.0290
# Denoising AE | Epoch [81/200], Loss: 0.0292
# Denoising AE | Epoch [82/200], Loss: 0.0290
# Denoising AE | Epoch [83/200], Loss: 0.0290
# Denoising AE | Epoch [84/200], Loss: 0.0290
# Denoising AE | Epoch [85/200], Loss: 0.0290
# Denoising AE | Epoch [86/200], Loss: 0.0289
# Denoising AE | Epoch [87/200], Loss: 0.0291
# Denoising AE | Epoch [88/200], Loss: 0.0289
# Denoising AE | Epoch [89/200], Loss: 0.0289
# Denoising AE | Epoch [90/200], Loss: 0.0290
# Denoising AE | Epoch [91/200], Loss: 0.0288
# Denoising AE | Epoch [92/200], Loss: 0.0290
# Denoising AE | Epoch [93/200], Loss: 0.0288
# Denoising AE | Epoch [94/200], Loss: 0.0288
# Denoising AE | Epoch [95/200], Loss: 0.0289
# Denoising AE | Epoch [96/200], Loss: 0.0288
# Denoising AE | Epoch [97/200], Loss: 0.0289
# Denoising AE | Epoch [98/200], Loss: 0.0288
# Denoising AE | Epoch [99/200], Loss: 0.0288
# Denoising AE | Epoch [100/200], Loss: 0.0287
# Denoising AE | Epoch [101/200], Loss: 0.0289
# Denoising AE | Epoch [102/200], Loss: 0.0286
# Denoising AE | Epoch [103/200], Loss: 0.0287
# Denoising AE | Epoch [104/200], Loss: 0.0287
# Denoising AE | Epoch [105/200], Loss: 0.0287
# Denoising AE | Epoch [106/200], Loss: 0.0287
# Denoising AE | Epoch [107/200], Loss: 0.0286
# Denoising AE | Epoch [108/200], Loss: 0.0286
# Denoising AE | Epoch [109/200], Loss: 0.0287
# Denoising AE | Epoch [110/200], Loss: 0.0287
# Denoising AE | Epoch [111/200], Loss: 0.0286
# Denoising AE | Epoch [112/200], Loss: 0.0286
# Denoising AE | Epoch [113/200], Loss: 0.0286
# Denoising AE | Epoch [114/200], Loss: 0.0286
# Denoising AE | Epoch [115/200], Loss: 0.0286
# Denoising AE | Epoch [116/200], Loss: 0.0285
# Denoising AE | Epoch [117/200], Loss: 0.0286
# Denoising AE | Epoch [118/200], Loss: 0.0285
# Denoising AE | Epoch [119/200], Loss: 0.0286
# Denoising AE | Epoch [120/200], Loss: 0.0285
# Denoising AE | Epoch [121/200], Loss: 0.0285
# Denoising AE | Epoch [122/200], Loss: 0.0285
# Denoising AE | Epoch [123/200], Loss: 0.0285
# Denoising AE | Epoch [124/200], Loss: 0.0285
# Denoising AE | Epoch [125/200], Loss: 0.0285
# Denoising AE | Epoch [126/200], Loss: 0.0285
# Denoising AE | Epoch [127/200], Loss: 0.0285
# Denoising AE | Epoch [128/200], Loss: 0.0285
# Denoising AE | Epoch [129/200], Loss: 0.0284
# Denoising AE | Epoch [130/200], Loss: 0.0285
# Denoising AE | Epoch [131/200], Loss: 0.0285
# Denoising AE | Epoch [132/200], Loss: 0.0284
# Denoising AE | Epoch [133/200], Loss: 0.0285
# Denoising AE | Epoch [134/200], Loss: 0.0284
# Denoising AE | Epoch [135/200], Loss: 0.0285
# Denoising AE | Epoch [136/200], Loss: 0.0285
# Denoising AE | Epoch [137/200], Loss: 0.0284
# Denoising AE | Epoch [138/200], Loss: 0.0283
# Denoising AE | Epoch [139/200], Loss: 0.0283
# Denoising AE | Epoch [140/200], Loss: 0.0284
# Denoising AE | Epoch [141/200], Loss: 0.0283
# Denoising AE | Epoch [142/200], Loss: 0.0283
# Denoising AE | Epoch [143/200], Loss: 0.0284
# Denoising AE | Epoch [144/200], Loss: 0.0283
# Denoising AE | Epoch [145/200], Loss: 0.0283
# Denoising AE | Epoch [146/200], Loss: 0.0283
# Denoising AE | Epoch [147/200], Loss: 0.0283
# Denoising AE | Epoch [148/200], Loss: 0.0283
# Denoising AE | Epoch [149/200], Loss: 0.0283
# Denoising AE | Epoch [150/200], Loss: 0.0283
# Denoising AE | Epoch [151/200], Loss: 0.0283
# Denoising AE | Epoch [152/200], Loss: 0.0284
# Denoising AE | Epoch [153/200], Loss: 0.0284
# Denoising AE | Epoch [154/200], Loss: 0.0283
# Denoising AE | Epoch [155/200], Loss: 0.0282
# Denoising AE | Epoch [156/200], Loss: 0.0283
# Denoising AE | Epoch [157/200], Loss: 0.0282
# Denoising AE | Epoch [158/200], Loss: 0.0284
# Denoising AE | Epoch [159/200], Loss: 0.0282
# Denoising AE | Epoch [160/200], Loss: 0.0283
# Denoising AE | Epoch [161/200], Loss: 0.0281
# Denoising AE | Epoch [162/200], Loss: 0.0283
# Denoising AE | Epoch [163/200], Loss: 0.0282
# Denoising AE | Epoch [164/200], Loss: 0.0282
# Denoising AE | Epoch [165/200], Loss: 0.0282
# Denoising AE | Epoch [166/200], Loss: 0.0283
# Denoising AE | Epoch [167/200], Loss: 0.0282
# Denoising AE | Epoch [168/200], Loss: 0.0282
# Denoising AE | Epoch [169/200], Loss: 0.0282
# Denoising AE | Epoch [170/200], Loss: 0.0282
# Denoising AE | Epoch [171/200], Loss: 0.0282
# Denoising AE | Epoch [172/200], Loss: 0.0282
# Denoising AE | Epoch [173/200], Loss: 0.0282
# Denoising AE | Epoch [174/200], Loss: 0.0282
# Denoising AE | Epoch [175/200], Loss: 0.0281
# Denoising AE | Epoch [176/200], Loss: 0.0281
# Denoising AE | Epoch [177/200], Loss: 0.0283
# Denoising AE | Epoch [178/200], Loss: 0.0281
# Denoising AE | Epoch [179/200], Loss: 0.0281
# Denoising AE | Epoch [180/200], Loss: 0.0281
# Denoising AE | Epoch [181/200], Loss: 0.0282
# Denoising AE | Epoch [182/200], Loss: 0.0281
# Denoising AE | Epoch [183/200], Loss: 0.0281
# Denoising AE | Epoch [184/200], Loss: 0.0281
# Denoising AE | Epoch [185/200], Loss: 0.0281
# Denoising AE | Epoch [186/200], Loss: 0.0283
# Denoising AE | Epoch [187/200], Loss: 0.0280
# Denoising AE | Epoch [188/200], Loss: 0.0281
# Denoising AE | Epoch [189/200], Loss: 0.0280
# Denoising AE | Epoch [190/200], Loss: 0.0281
# Denoising AE | Epoch [191/200], Loss: 0.0281
# Denoising AE | Epoch [192/200], Loss: 0.0280
# Denoising AE | Epoch [193/200], Loss: 0.0281
# Denoising AE | Epoch [194/200], Loss: 0.0280
# Denoising AE | Epoch [195/200], Loss: 0.0281
# Denoising AE | Epoch [196/200], Loss: 0.0281
# Denoising AE | Epoch [197/200], Loss: 0.0281
# Denoising AE | Epoch [198/200], Loss: 0.0280
# Denoising AE | Epoch [199/200], Loss: 0.0281
# Denoising AE | Epoch [200/200], Loss: 0.0280
#
# --- Visualizando resultados do Denoising Autoencoder ---
